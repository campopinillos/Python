# %% [markdown]
# # Taller Plotly - NBA

# %% [markdown]
# La NBA es la máxima competición de baloncesto masculino en Estados Unidos. Está compuesta por 30 equipos divididos en dos conferencias (Este y Oeste). Cada equipo disputa 82 partidos de temporada regular. Luego los 8 mejores equipos de cada conferencia disputan un formato de eliminación directa. Finalmente los ganadores de cada conferencia se enfrentan en la final por el titulo. Analizaremos los datos de los jugadores de la NBA en la temporada 2014-2015, en la cual se coronaron los Golden State Warriors ante los Cleveland Cavaliers.
#
# En este taller se propone una serie de ejercicios con el objetivo de visualizar qué efectos influyen en el rendimiento de un jugador (Posición, edad, experiencia, efectividad). Por ejemplo, un jugador de perfil defensivo tendrá un alto número de rebotes, robos y bloqueos por partido; mientras un jugador de perfil ofensivo tendrá un alto porcentaje de tiros encestados sobre tiros intentados. El taller está compuesto por 5 ejercicios, que usarán diferentes herramientas de Plot.ly. Usted deberá completar las celdas de código dónde sea necesario.
#
# **NOTA: LOS COMANDOS PARA GRAFICAR UNA FIGURA DEBERÍAN IR TODOS EN UNA MISMA CELDA. AL SEPARARLOS EN CELDAS DISTINTAS PUEDE CAUSAR QUE NO SE GRAFIQUE NADA.**

# %% [markdown]
# ### Instalación
#
# Es necesario instalar plotly y cufflinks para crear gráficos directamente desde los DataFrames de Pandas.
# Instale las librerías desde su línea de comandos usando:
#
#     pip install plotly==3.9.0
#     pip install cufflinks==0.15

# %%
# !pip install plotly==3.9.0
# !pip install cufflinks==0.15
# Out:
# Requirement already satisfied: plotly==3.9.0 in /usr/local/lib/python3.6/dist-packages (3.9.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly==3.9.0) (1.3.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly==3.9.0) (2.21.0)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from plotly==3.9.0) (1.12.0)
# Requirement already satisfied: pytz in /usr/local/lib/python3.6/dist-packages (from plotly==3.9.0) (2018.9)
# Requirement already satisfied: decorator>=4.0.6 in /usr/local/lib/python3.6/dist-packages (from plotly==3.9.0) (4.4.0)
# Requirement already satisfied: nbformat>=4.2 in /usr/local/lib/python3.6/dist-packages (from plotly==3.9.0) (4.4.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.9.0) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.9.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.9.0) (2019.3.9)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly==3.9.0) (3.0.4)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.9.0) (0.2.0)
# Requirement already satisfied: traitlets>=4.1 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.9.0) (4.3.2)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.9.0) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2->plotly==3.9.0) (2.6.0)
# Requirement already satisfied: cufflinks==0.15 in /usr/local/lib/python3.6/dist-packages (0.15)
# Requirement already satisfied: colorlover>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (0.3.0)
# Requirement already satisfied: numpy>=1.9.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (1.16.3)
# Requirement already satisfied: setuptools>=34.4.1 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (41.0.1)
# Requirement already satisfied: pandas>=0.19.2 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (0.24.2)
# Requirement already satisfied: ipywidgets>=7.0.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (7.4.2)
# Requirement already satisfied: ipython>=5.3.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (5.5.0)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (1.12.0)
# Requirement already satisfied: plotly>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from cufflinks==0.15) (3.9.0)
# Requirement already satisfied: pytz>=2011k in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks==0.15) (2018.9)
# Requirement already satisfied: python-dateutil>=2.5.0 in /usr/local/lib/python3.6/dist-packages (from pandas>=0.19.2->cufflinks==0.15) (2.5.3)
# Requirement already satisfied: nbformat>=4.2.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks==0.15) (4.4.0)
# Requirement already satisfied: widgetsnbextension~=3.4.0 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks==0.15) (3.4.2)
# Requirement already satisfied: traitlets>=4.3.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks==0.15) (4.3.2)
# Requirement already satisfied: ipykernel>=4.5.1 in /usr/local/lib/python3.6/dist-packages (from ipywidgets>=7.0.0->cufflinks==0.15) (4.6.1)
# Requirement already satisfied: pygments in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks==0.15) (2.1.3)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks==0.15) (0.7.5)
# Requirement already satisfied: prompt-toolkit<2.0.0,>=1.0.4 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks==0.15) (1.0.16)
# Requirement already satisfied: simplegeneric>0.8 in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks==0.15) (0.8.1)
# Requirement already satisfied: pexpect; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks==0.15) (4.7.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.6/dist-packages (from ipython>=5.3.0->cufflinks==0.15) (4.4.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from plotly>=3.0.0->cufflinks==0.15) (2.21.0)
# Requirement already satisfied: retrying>=1.3.3 in /usr/local/lib/python3.6/dist-packages (from plotly>=3.0.0->cufflinks==0.15) (1.3.3)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.15) (4.4.0)
# Requirement already satisfied: jsonschema!=2.5.0,>=2.4 in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.15) (2.6.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.6/dist-packages (from nbformat>=4.2.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.2.0)
# Requirement already satisfied: notebook>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (5.2.2)
# Requirement already satisfied: tornado>=4.0 in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.15) (4.5.3)
# Requirement already satisfied: jupyter-client in /usr/local/lib/python3.6/dist-packages (from ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.15) (5.2.4)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.6/dist-packages (from prompt-toolkit<2.0.0,>=1.0.4->ipython>=5.3.0->cufflinks==0.15) (0.1.7)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.6/dist-packages (from pexpect; sys_platform != "win32"->ipython>=5.3.0->cufflinks==0.15) (0.6.0)
# Requirement already satisfied: idna<2.9,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->plotly>=3.0.0->cufflinks==0.15) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->plotly>=3.0.0->cufflinks==0.15) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->plotly>=3.0.0->cufflinks==0.15) (2019.3.9)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->plotly>=3.0.0->cufflinks==0.15) (1.24.3)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (5.5.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (2.10.1)
# Requirement already satisfied: terminado>=0.3.3; sys_platform != "win32" in /usr/local/lib/python3.6/dist-packages (from notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.8.2)
# Requirement already satisfied: pyzmq>=13 in /usr/local/lib/python3.6/dist-packages (from jupyter-client->ipykernel>=4.5.1->ipywidgets>=7.0.0->cufflinks==0.15) (17.0.0)
# Requirement already satisfied: mistune>=0.8.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.8.4)
# Requirement already satisfied: testpath in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.4.2)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (1.4.2)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.6.0)
# Requirement already satisfied: bleach in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (3.1.0)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.6/dist-packages (from nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.3)
# Requirement already satisfied: MarkupSafe>=0.23 in /usr/local/lib/python3.6/dist-packages (from jinja2->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (1.1.1)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.6/dist-packages (from bleach->nbconvert->notebook>=4.4.1->widgetsnbextension~=3.4.0->ipywidgets>=7.0.0->cufflinks==0.15) (0.5.1)

# %% [markdown]
# ### Importar y configurar

# %%
import pandas as pd
import numpy as np
# %matplotlib inline

# %%
import cufflinks as cf
print(cf.__version__)
# Out:
# 0.15

# %%
import plotly.graph_objs as go
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot

# %%
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-latest.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
def configure_plotly_browser_state():
  import IPython
  display(IPython.core.display.HTML('''
        <script src="/static/components/requirejs/require.js"></script>
        <script>
          requirejs.config({
            paths: {
              base: '/static/base',
              plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
            },
          });
        </script>
        '''))

# %% [markdown]
# ## Carga de Datos
#
# **IMPORTANTE:** Primero debe cargar el archivo **'nba_players_stats.csv'** en su directorio de Colab.

# %%
nba_players = pd.read_csv('nba_players_stats.csv')

# %% [markdown]
# A continuación observamos el DataFrame que contiene la información de casi 490 jugadores que estuvieron involucrados en la temporada 2014-2015 de la NBA.

# %%
nba_players.head()
# Out:
#             Name  Games Played   MIN   PTS  ...  Pos  Team  Weight        BMI
# 0       AJ Price            26   324   133  ...   PG   PHO   81.45  23.798393
# 1   Aaron Brooks            82  1885   954  ...   PG   CHI   72.45  22.361111
# 2   Aaron Gordon            47   797   243  ...   PF   ORL   99.00  24.142661
# 3  Adreian Payne            32   740   213  ...   PF   ATL  106.65  25.377751
# 4     Al Horford            76  2318  1156  ...    C   ATL  110.25  26.234384
#
# [5 rows x 34 columns]

# %%
nba_players.columns
# Out:
# Index(['Name', 'Games Played', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA',
#        '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK',
#        'TOV', 'PF', 'EFF', 'AST/TOV', 'STL/TOV', 'Age', 'Birth_Place',
#        'Birthdate', 'Collage', 'Experience', 'Height', 'Pos', 'Team', 'Weight',
#        'BMI'],
#       dtype='object')

# %% [markdown]
# ## Descripción de cada variable
#
# - Name: Nombre del jugador
# - Games Played: Juegos disputados sobre un máximo de 82 juegos de la temporada regular.
# - MIN: Minutos disputados en la temporada.
# - PTS: Puntos anotados en la temporada.
# - FGM: Tiros anotados. Aquí un disparo se cuenta igual tanto desde afuera de la línea de 3, como dentro de esta.
# - FGA: Tiros intentados.
# - FG%: FGM/FGA.
# - 3PM: Tiros de 3 puntos anotados.
# - 3PA: Tiros de 3 puntos intentados.
# - 3P%: 3PM/3PA.
# - FTM: Tiros libres anotados.
# - FTA: Tiros libres intentados.
# - FT%: FTM/FTA.
# - OREB: Rebotes ofensivos.
# - OREB: Rebotes defensivos.
# - AST: Asistencias.
# - STL: Robos de balón.
# - BLK: Bloqueos de balón.
# - TOV: Pérdidas de balón.
# - PF: Faltas personales.
# - EFF: Eficiencia.
# - AST/TOV: Porcentaje de asistencias por pérdida.
# - STL/TOV: Porcentaje de robos por pérdida.
# - Age: Edad al finalizar la temporada 2014-2015 (Abril 2015).
# - Birth_Place: Lugar de nacimiento.
# - *Collage*: College, universidad de la cual salió el jugador.
# - Experience: Indicador de experiencia del jugador.
# - Height: Altura del jugador en cm.
# - Pos: Posición. Valores posibles: PG, SG, SF, PF, C. [Posiciones](https://es.wikipedia.org/wiki/Posiciones_del_baloncesto)
# - Team: Equipo con el que terminó disputando la temporada.
# - Weight: Peso en kg.
# - BMI: Body Mass Index. Índice de masa corporal.

# %% [markdown]
# # TALLER

# %% [markdown]
# ## 1. ¿Cómo se comporta el número de tiros encestados con respecto a la edad de un jugador?
#
# La efectividad de lanzamientos al aro se mide con la estadística ```FG%```, y la vamos a comparar con la edad del jugador. Con el objetivo de evaluar si la edad influye en la efectivdad de lanzamientos al aro. Vale la pena anotar que aquí no se cuentan los tiros libres.

# %%
# Escriba su código aquí
configure_plotly_browser_state()

nba_players.iplot(kind='scatter',x='Age',y='FG%',mode='markers',bestfit=True,
                  bestfit_colors=['blue'],xTitle='Edad',yTitle = 'Efectividad de lanzamientos al aro')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# /usr/local/lib/python3.6/dist-packages/numpy/core/fromnumeric.py:2389: FutureWarning:
#
# Method .ptp is deprecated and will be removed in a future version. Use numpy.ptp instead.
# <div>
#
#
#             <div id="04c4a2bb-0c6b-46ec-92ed-1314e6148ef5" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("04c4a2bb-0c6b-46ec-92ed-1314e6148ef5")) {
#                     Plotly.newPlot(
#                         '04c4a2bb-0c6b-46ec-92ed-1314e6148ef5',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 12, "symbol": "circle"}, "mode": "markers", "name":
35.0, 24.0, 27.0, 27.0, null, null, 23.0, 33.0, 30.0, null, null, 38.0, 33.0, 21.0, 26.0, 35.0, 23.0, null, 27.0, 22.0, 24.0, null, 25.0, 20.0, 27.0, 28.0, 25.0, 29.0, 27.0, 22.0, 38.0, 27.0, 27.0, null, 27.0, 35.0, 25.0, 30.0, 38.0, 33.0, 24.0, 24.0, 23.0, null, 25.0, 23.0, 27.0, 29.0, 29.0, 32.0, 36.0, 24.0, 31.0, 24.0, 35.0, 25.0, null, 35.0, null, 23.0, 26.0, 25.0, null, 27.0, 23.0, 29.0, 32.0, null, 29.0, 29.0, 23.0, 24.0, null, 27.0, 31.0, 24.0, 34.0, 25.0, null, 26.0, 22.0, 25.0, 23.0, null, 23.0, 30.0, 30.0, 32.0, 37.0, 24.0, null, 25.0, 23.0, 24.0, 22.0, 27.0, 27.0, 35.0, 32.0, 22.0, 30.0, 24.0, 35.0, 23.0, 24.0, 31.0, null, null, 30.0, 39.0, 25.0, 23.0, 29.0, null, 23.0, 29.0, 33.0, 33.0, 24.0, null, 26.0, null, 30.0, 28.0, 23.0, null, 24.0, 28.0, 21.0, 30.0, 23.0, null, 26.0, null, 33.0, 35.0, 23.0, 27.0, 23.0, 38.0, 28.0, 28.0, 29.0, 24.0, 32.0, 24.0, 34.0, 28.0, 24.0, 20.0, 34.0, 31.0, 26.0], "y": [37.2, 42.1, 44.7, 41.4, 53.8, 48.1, 44.3, 40.3, 25.0, 50.7, 39.7, 55.0, 41.2, 41.2, 46.8, 55.7, 57.4, 55.5, 16.7, 51.4, 46.6, 50.0, 45.8, 45.4, 0.0, 56.3, 43.7, 43.7, 42.1, 53.5, 46.3, 41.0, 39.3, 85.7, 56.6, 42.4, 35.5, 40.9, 42.8, 43.7, 43.7, 48.7, 44.4, 54.3, 50.2, 45.3, 46.0, 42.7, 64.2, 50.4, 40.1, 40.1, 42.2, 20.4, 46.7, 38.9, 51.3, 33.3, 42.0, 43.4, 21.4, 51.5, 49.9, 44.4, 40.7, 28.3, 46.2, 39.2, 41.4, 43.3, 58.0, 46.0, 36.1, 23.8, 40.3, 51.5, 48.5, 47.8, 43.6, 39.8, 42.1, 35.5, 48.3, 46.1, 47.8, 42.6, 44.9, 50.4, 44.8, 39.9, 28.6, 43.4, 45.2, 40.1, 40.1, 43.6, 45.7, 34.9, 14.3, 34.0, 40.4, 47.3, 51.1, 33.3, 0.0, 47.1, 71.0, 45.6, 41.3, 46.7, 48.7, 42.7, 38.7, 52.5, 40.5, 44.7, 41.8, 31.8, 56.2, 39.6, 45.9, 40.8, 50.4, 37.9, 40.2, 44.3, 39.9, 42.1, 45. ...

# %% [markdown]
# Debe obtener el siguiente resultado:
# [click aquí](https://drive.google.com/file/d/1HfjGBiZRsYbo3Rf8RqR1J30IFk5TOkum/view)

# %% [markdown]
# ## 2. ¿Cómo está distribuída la edad de los jugadores? ¿Cómo está distribuída la edad promedio por equipos?
#
# La NBA admite jugadores desde los 19 años, los cuales si mantienen un buen nivel, pueden durar hasta 15 temporadas. Para este punto, estamos interesados en observar como está distribuída la edad de los jugadores de la NBA. De igual forma, observaremos cuál es la edad promedio de las plantillas de cada equipo.

# %%
# Histograma por edad
# Escriba su código aquí

configure_plotly_browser_state()
nba_players['Age'].iplot(kind='hist',xTitle='Edad',yTitle = 'Frecuencia de Edad')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id
, 37.0, 26.0, 25.0, 30.0, 22.0, 34.0, 29.0, 25.0, 27.0, 23.0, 30.0, 25.0, null, 27.0, 24.0, 25.0, null, 26.0, 33.0, 31.0, 31.0, 25.0, 33.0, 29.0, 29.0, 23.0, 35.0, 26.0, 34.0, 30.0, 25.0, 38.0, 30.0, 31.0, 29.0, 26.0, 21.0, null, 29.0, 23.0, 26.0, 28.0, null, 29.0, 25.0, 35.0, 35.0, 25.0, 22.0, 23.0, 26.0, 24.0, 22.0, 28.0, 35.0, 35.0, 24.0, 27.0, 27.0, null, null, 23.0, 33.0, 30.0, null, null, 38.0, 33.0, 21.0, 26.0, 35.0, 23.0, null, 27.0, 22.0, 24.0, null, 25.0, 20.0, 27.0, 28.0, 25.0, 29.0, 27.0, 22.0, 38.0, 27.0, 27.0, null, 27.0, 35.0, 25.0, 30.0, 38.0, 33.0, 24.0, 24.0, 23.0, null, 25.0, 23.0, 27.0, 29.0, 29.0, 32.0, 36.0, 24.0, 31.0, 24.0, 35.0, 25.0, null, 35.0, null, 23.0, 26.0, 25.0, null, 27.0, 23.0, 29.0, 32.0, null, 29.0, 29.0, 23.0, 24.0, null, 27.0, 31.0, 24.0, 34.0, 25.0, null, 26.0, 22.0, 25.0, 23.0, null, 23.0, 30.0, 30.0, 32.0, 37.0, 24.0, null, 25.0, 23.0, 24.0, 22.0, 27.0, 27.0, 35.0, 32.0, 22.0, 30.0, 24.0, 35.0, 23.0, 24.0, 31.0, null, null, 30.0, 39.0, 25.0, 23.0, 29.0, null, 23.0, 29.0, 33.0, 33.0, 24.0, null, 26.0, null, 30.0, 28.0, 23.0, null, 24.0, 28.0, 21.0, 30.0, 23.0, null, 26.0, null, 33.0, 35.0, 23.0, 27.0, 23.0, 38.0, 28.0, 28.0, 29.0, 24.0, 32.0, 24.0, 34.0, 28.0, 24.0, 20.0, 34.0, 31.0, 26.0]}],
#                         {"barmode": "overlay", "legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Edad"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Frecuencia de Edad"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('261c2648-27fb-474f-aaec-9c533c341d61');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Debe obtener el siguiente resultado:
# [click aquí](https://drive.google.com/file/d/1AVdky3k6p83Zbu5YgyCxaGF72ZX5vfnl/view)

# %%
# Edad promedio por equipo
df = nba_players.groupby(['Team']).mean()

# %%
# Escriba su código aquí
configure_plotly_browser_state()

df['Age'].iplot(kind='bar',yTitle='Edad Promedio',xTitle = 'Equipo')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="6743706b-3f89-462f-b4fa-280728d045b3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("6743706b-3f89-462f-b4fa-280728d045b3")) {
#                     Plotly.newPlot(
#                         '6743706b-3f89-462f-b4fa-280728d045b3',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "Age", "orientation": "v", "text": "", "type": "bar", "uid": "29fb9422-6f82-4bcc-b6f0-8cf18ac4dd70", "x": ["ATL", "BOS", "CHA", "CHI", "CLE", "DAL", "DEN", "DET", "GSW", "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NJN", "NOH", "NYK", "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"], "y": [28.066666666666666, 25.625, 27.285714285714285, 29.071428571428573, 29.166666666666668, 29.733333333333334, 26.181818181818183, 27.727272727272727, 27.6, 26.90909090909091, 28.733333333333334, 29.428571428571427, 26.75, 29.0, 29.166666666666668, 27.083333333333332, 26.875, 27.76923076923077, 26.3125, 28.1875, 26.666666666666668, 25.933333333333334, 25.0, 26.0625, 27.375, 26.53846153846154, 29.4375, 26.928571428571427, 24.375, 29.8125]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Equipo"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Edad Promedio"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('6743706b-3f89-462f-b4fa-280728d045b3');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Debe obtener el siguiente resultado:
# [click aquí](https://drive.google.com/file/d/1vCKR4wLLBitUfoJE1McjOQN7fbJfI_nR/view)

# %% [markdown]
# ## 3. ¿Se relacionan las asistencias con la cantidad de perdidas de balón de un jugador? ¿Varían por posición?
#
# El baloncesto cuenta con 5 posiciones tradicionales: Point Guard o Base en español (Stephen Curry, Magic Johnson), Shooting Guard o Escolta (Kobe Bryant, Michael Jordan), Small Forward o Alero (Kevin Durant, Lebron James), Power Forward o Ala-Pivot (Dennis Rodman) y Center o Pivote (Shaquille O'Neal, Hakeem Olajuwon). Para facilidad del ejercicio, vamos a resumir estas posiciones en 3:
# - Guardia
# - Alero
# - Pivot o Poste
#
# Los guardias por lo general son quienes llevan el balón y reparten el juego. Por lo tanto deben tener un alto número de asistencias y robos. Sin embargo, también tienden a **perder el balón** (Turnover en inglés). A continuación se hace un análisis de cómo se comporta el número de pérdidas con respecto a la cantidad de asistencias de un jugador.

# %%
nba_players['Short Pos'] = float('NaN')

nba_players.loc[nba_players['Pos'] == 'PG', 'Short Pos'] = 'G'
nba_players.loc[nba_players['Pos'] == 'SG', 'Short Pos'] = 'G'
nba_players.loc[nba_players['Pos'] == 'SF', 'Short Pos'] = 'F'
nba_players.loc[nba_players['Pos'] == 'PF', 'Short Pos'] = 'F'
nba_players.loc[nba_players['Pos'] == 'C', 'Short Pos'] = 'C'
nba_players.head()
# Out:
#             Name  Games Played   MIN  ...        BMI  Short Pos        MPP
# 0       AJ Price            26   324  ...  23.798393          G  12.461538
# 1   Aaron Brooks            82  1885  ...  22.361111          G  22.987805
# 2   Aaron Gordon            47   797  ...  24.142661          F  16.957447
# 3  Adreian Payne            32   740  ...  25.377751          F  23.125000
# 4     Al Horford            76  2318  ...  26.234384          C  30.500000
#
# [5 rows x 36 columns]

# %% [markdown]
# Para este caso, crearemos un DataFrame donde solo tendremos en cuenta a los jugadores con más de 20 minutos por partido. Es decir aquellos jugadores principales de cada nómina.

# %%
nba_players['MPP'] = nba_players['MIN'] / nba_players['Games Played']

top_players = nba_players.loc[nba_players.MPP > 20]

# %%
df = top_players.copy()
df = df.loc[df['Short Pos'] == 'G']
df.head()
# Out:
#               Name  Games Played   MIN  ...        BMI  Short Pos        MPP
# 1     Aaron Brooks            82  1885  ...  22.361111          G  22.987805
# 6    Alan Anderson            74  1744  ...  26.035503          G  23.567568
# 7       Alec Burks            27   899  ...  25.325444          G  33.296296
# 30  Anthony Morrow            74  1806  ...  25.501771          G  24.405405
# 35   Arron Afflalo            78  2502  ...  25.501771          G  32.076923
#
# [5 rows x 36 columns]

# %%
# Escriba su código aquí
configure_plotly_browser_state()
df.iplot(kind='scatter', x='AST', y='TOV', yTitle='Perdidas',xTitle = 'Asistencias',mode='markers')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="47257237-de60-45bb-b226-ca98ff4628c8" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("47257237-de60-45bb-b226-ca98ff4628c8")) {
#                     Plotly.newPlot(
#                         '47257237-de60-45bb-b226-ca98ff4628c8',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 12, "symbol": "circle"}, "mode": "markers", "name": "TOV", "text": "", "type": "scatter", "uid": "29683386-7012-4423-b004-2f11cc188b75", "x": [261, 83, 82, 60, 129, 155, 135, 140, 194, 272, 330, 208, 838, 75, 151, 353, 507, 158, 198, 252, 210, 251, 237, 190, 14, 533, 493, 229, 120, 100, 220, 206, 207, 350, 302, 135, 284, 40, 158, 253, 565, 130, 373, 38, 513, 339, 233, 212, 137, 79, 292, 206, 198, 195, 274, 318, 109, 89, 148, 72, 222, 197, 196, 473, 389, 240, 150, 164, 293, 94, 208, 307, 204, 442, 375, 424, 329, 255, 197, 192, 538, 119, 188, 462, 193, 83, 219, 165, 44, 226, 619, 60, 127, 86, 335, 328, 720, 521, 8, 295, 105, 139, 276], "y": [157, 60, 52, 38, 116, 65, 109, 138, 123, 90, 189, 100, 190, 73, 78, 145, 222, 93, 118, 112, 137, 161, 85, 65, 12, 203, 274, 122, 82, 65, 69, 110, 173, 173, 119, 91, 143, 32, 92, 109, 321, 62, 191, 16, 205, 166, 133, 93, 95, 57, 137, 96, 75, 97, 91, 100, 94, 76, 73, 105, 149, 128, 107, 173, 186, 128, 61, 101, 154, 61, 90, 173, 61, 253, 156, 172, 198, 99, 128, 83, 210, 60, 85, 186, 64, 45, 118, 52, 35, 83, 249, 25, 82, 86, 146, 124, 185, 246, 6, 204, 50, 81, 193]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Asistencias"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Perdidas"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('47257237-de60-45bb-b226-ca98ff4628c8');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Debe obtener el siguiente resultado:
# [click aquí](https://drive.google.com/file/d/1APEuqPB5XTv-g2gFGVzK16z5nJcwYK9-/view)

# %% [markdown]
# ## 4. ¿Cómo se comportan las estadísticas por equipo de porcentaje de triples y porcentaje de tiros anotados? ¿Cómo varían por posición (Guardia, Alero y Pívot)?
#
# El porcentaje de triples por posición permite saber qué tan buen juego externo tiene un equipo. Es deseable que jugadores altos tengan un triple, porque esto le da variantes ofensivas a los técnicos. Para este punto, primero agruparemos las estadísticas de los jugadores por `Team` y `ShortPos`. Luego calcularemos el promedio sobre esas agrupaciones:

# %%
team_df = top_players.groupby(['Team', 'Short Pos'])
mean_stats_team = team_df.mean()

# %% [markdown]
# De esta forma tendremos el promedio de cada estadística, por posición y por equipo.

# %%
mean_stats_team.head(10)
# Out:
#                 Games Played          MIN  ...        BMI        MPP
# Team Short Pos                             ...
# ATL  C             76.000000  2318.000000  ...  26.234384  30.500000
#      F             58.333333  1773.000000  ...  25.746750  29.045385
#      G             74.000000  2323.000000  ...  24.456713  31.380274
# BOS  C             64.000000  1424.000000  ...  24.285714  22.250000
#      F             70.000000  1747.500000  ...  28.328618  25.262195
#      G             70.333333  1987.333333  ...  26.356016  28.092912
# CHA  C             65.000000  1992.000000  ...  30.945866  30.646154
#      F             66.500000  1811.000000  ...  26.386586  27.472145
#      G             67.750000  1996.750000  ...  26.007521  29.504863
# CHI  C             67.000000  2049.000000  ...  24.038322  30.582090
#
# [10 rows x 28 columns]

# %% [markdown]
# En este caso, deseamos conocer solo el porcentaje promedio de triples por equipo. Esta operación se puede hacer usando ```pd.unstack()```. [Unstack](https://pandas.pydata.org/pandas-docs/stable/reshaping.html) convierte los valores únicos de un índice en columnas de un DataFrame.

# %%
team_3p_mean = team_df.mean()['3P%']

# %%
team_3p_mean.head()
# Out:
# Team  Short Pos
# ATL   C            30.600000
#       F            28.733333
#       G            41.750000
# BOS   C            34.900000
#       F            28.200000
# Name: 3P%, dtype: float64

# %%
team_3p_mean = team_3p_mean.unstack(level=-1)

# %%
team_3p_mean.reset_index(inplace=True)

# %%
team_3p_mean.head()
# Out:
# Short Pos Team     C          F          G
# 0          ATL  30.6  28.733333  41.750000
# 1          BOS  34.9  28.200000  35.333333
# 2          CHA  40.0  17.900000  28.700000
# 3          CHI   0.0  29.625000  34.750000
# 4          CLE  33.3  36.050000  41.100000

# %%
# Escriba su código aquí
configure_plotly_browser_state()

team_3p_mean.iplot(kind='bar', x= 'Team', y = ['C','F','G'],title='Promedio de Triples por Equipo y Posición',
                   yTitle='3P%',xTitle = 'Equipo')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="afe191f2-9376-437e-80e2-b60863521919" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("afe191f2-9376-437e-80e2-b60863521919")) {
#                     Plotly.newPlot(
#                         'afe191f2-9376-437e-80e2-b60863521919',
#                         [{"marker": {"color": "rgba(255, 153, 51, 0.6)", "line": {"color": "rgba(255, 153, 51, 1.0)", "width": 1}}, "name": "C", "orientation": "v", "text": "", "type": "bar", "uid": "dc0df233-7215-4bad-9c89-a3fa7c008738", "x": ["ATL", "BOS", "CHA", "CHI", "CLE", "DAL", "DEN", "DET", "GSW", "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NJN", "NOH", "NYK", "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"], "y": [30.6, 34.9, 40.0, 0.0, 33.3, 0.0, "", 0.0, 13.85, 50.0, 0.0, 25.0, 27.3, 17.6, 37.5, 0.0, 16.7, 5.0, 0.0, 36.6, 17.8, 33.3, 0.0, 33.3, 0.0, 25.0, 28.6, 0.0, 0.0, 0.0]}, {"marker": {"color": "rgba(55, 128, 191, 0.6)", "line": {"color": "rgba(55, 128, 191, 1.0)", "width": 1}}, "name": "F", "orientation": "v", "text": "", "type": "bar", "uid": "ccaf1647-51a6-48b1-a4b6-fadba0d148b0", "x": ["ATL", "BOS", "CHA", "CHI", "CLE", "DAL", "DEN", "DET", "GSW", "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NJN", "NOH", "NYK", "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"], "y": [28.733333333333334, 28.200000000000003, 17.9, 29.625000000000004, 36.05, 35.1, 27.400000000000002, 18.95, 36.36666666666667, 35.63333333333333, 25.900000000000002, 38.1, 17.175, 38.166666666666664, 31.566666666666666, 39.8, 20.55, 35.5, 22.4, 34.1, 39.23333333333333, 37.849999999999994, 33.166666666666664, 33.8, 33.8, 38.05, 33.45, 39.25, 29.566666666666663, 24.4]}, {"marker": {"color": "rgba(50, 171, 96, 0.6)", "line": {"color": "rgba(50, 171, 96, 1.0)", "width": 1}}, "name": "G", "orientation": "v", "text": "", "type": "bar", "uid": "9a0b1ab5-30e3-464b-8a43-f2d1a532a23c", "x": ["ATL", "BOS", "CHA", "CHI", "CLE", "DAL", "DEN", "DET", "GSW", "HOU", "IND", "LAC", "LAL", "MEM", "MIA", "MIL", "MIN", "NJN", "NOH", "NYK", "OKC", "ORL", "PHI", "PHO", "POR", "SAC", "SAS", "TOR", "UTA", "WAS"], "y": [41.75, 35.333333333333336, 28.7, 34.75, 41.1, 32.525, 34.900000000000006, 35.13333333333333, 44.099999999999994, 36.55, 36.12, 38.733333333333334, 35.462500000000006, 37.76666666666667, 29.4, 30.225, 35.775, 32.46666666666667, 34.82, 34.15714285714285, 35.666666666666664, 32.63333333333333, 28.166666666666668, 35.333333333333336, 34.5, 34.56666666666666, 39.099999999999994, 33.525, 34.475, 40.9]}],
#                         {"legend": {"bgcolor": "#F5F6F9", "font": {"color": "#4D5663"}}, "paper_bgcolor": "#F5F6F9", "plot_bgcolor": "#F5F6F9", "title": {"font": {"color": "#4D5663"}, "text": "Promedio de Triples por Equipo y Posici\u00f3n"}, "xaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "Equipo"}, "zerolinecolor": "#E1E5ED"}, "yaxis": {"gridcolor": "#E1E5ED", "showgrid": true, "tickfont": {"color": "#4D5663"}, "title": {"font": {"color": "#4D5663"}, "text": "3P%"}, "zerolinecolor": "#E1E5ED"}},
#                         {"showLink": true, "linkText": "Export to plot.ly", "plotlyServerURL": "https://plot.ly", "responsive": true}
#                     ).then(function(){
#
# var gd = document.getElementById('afe191f2-9376-437e-80e2-b60863521919');
# var x = new MutationObserver(function (mutations, observer) {{
#         var display = window.getComputedStyle(gd).display;
#         if (!display || display === 'none') {{
#             console.log([gd, 'removed!']);
#             Plotly.purge(gd);
#             observer.disconnect();
#         }}
# }});
#
# // Listen for the removal of the full notebook cells
# var notebookContainer = gd.closest('#notebook-container');
# if (notebookContainer) {{
#     x.observe(notebookContainer, {childList: true});
# }}
#
# // Listen for the clearing of the current output cell
# var outputEl = gd.closest('.output');
# if (outputEl) {{
#     x.observe(outputEl, {childList: true});
# }}
#
#                         })
#                 };
#                 });
#             </script>
#         </div>

# %% [markdown]
# Debe obtener el siguiente resultado:
# [click aquí](https://drive.google.com/file/d/1u-G2YdUXIwM7QLEo7LjtAvWXcoKdyk6i/view)

# %% [markdown]
# ## 5. ¿Cómo se comporta el porcentaje de triples con respecto a la altura del jugador?

# %%
# Escriba su código aquí
configure_plotly_browser_state()
nba_players.iplot(kind='scatter',x='Height',y='3P%',mode='markers',
                  xTitle='Altura',yTitle = '3P%', title='Porcentaje de Triples vs Altura')
# Out:
#         <script src="/static/components/requirejs/require.js"></script>
#         <script>
#           requirejs.config({
#             paths: {
#               base: '/static/base',
#               plotly: 'https://cdn.plot.ly/plotly-latest.min.js?noext',
#             },
#           });
#         </script>
# <div>
#
#
#             <div id="a2258dc4-c5be-4df4-aa55-f5104afb54b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#                     window.PLOTLYENV.BASE_URL='https://plot.ly';
#
#                 if (document.getElementById("a2258dc4-c5be-4df4-aa55-f5104afb54b2")) {
#                     Plotly.newPlot(
#                         'a2258dc4-c5be-4df4-aa55-f5104afb54b2',
#                         [{"line": {"color": "rgba(255, 153, 51, 1.0)", "dash": "solid", "shape": "linear", "width": 1.3}, "marker": {"size": 12, "symbol": "circle"}, "mode": "markers", "name": "3P%", "text": "", "type": "scatter", "uid": "8a538e07-7660-49a7-9b82-e07a8afb79c0", "x": [185.0, 180.0, 202.5, 205.0, 205.0, 205.0, 195.0, 195.0, 210.0, 212.5, 195.0, 215.0, 202.5, 195.0, 195.0, null, 202.5, null, 192.5, 207.5, 195.0, 187.5, 197.5, 210.0, 202.5, 210.0, 202.5, null, 200.0, 205.0, 192.5, null, 192.5, 202.5, 205.0, 192.5, 207.5, 190.0, 185.0, 187.5, 192.5, null, 205.0, 202.5, 205.0, 200.0, 200.0, 192.5, null, 200.0, 205.0, 182.5, 187.5, 195.0, 210.0, 182.5, 210.0, 202.5, 182.5, 185.0, 202.5, 202.5, 202.5, 200.0, 197.5, 197.5, 205.0, 207.5, null, 197.5, 205.0, 207.5, 202.5, 197.5, 195.0, 210.0, 180.0, 195.0, 190.0, 195.0, null, 200.0, 205.0, null, 207.5, 202.5, 202.5, 187.5, 192.5, 180.0, 195.0, 187.5, 205.0, 205.0, 202.5, 195.0, 200.0, 195.0, 200.0, 190.0, 202.5, 180.0, 202.5, 177.5, null, 202.5, 207.5, 197.5, 197.5, 207.5, 200.0, 182.5, null, 205.0, 187.5, null, 187.5, 195.0, 210.0, null, 210.0, 187.5, 210.0, null, 200.0, 197.5, 205.0, 202.5, 187.5, 207.5, 207.5, null, 210.0, 205.0, 205.0, null, 190.0, null, null, 200.0, 207.5, 182.5, 190.0, 190.0, 205.0, 190.0, 197.5, 207.5, null, 197.5, 205.0, 187.5, 195.0, 190.0, 190.0, 187.5, 197.5, 192.5, null, 207.5, null, 202.5, 195.0, null, 187.5, 200.0, 207.5, 205.0, 207.5, 205.0, 207.5, 195.0, 200.0, null, null, null, null, null, 187.5, 207.5, 192.5, 180.0, 172.5, null, 180.0, 190.0, null, 202.5, 195.0, null, 192.5, 192.5, 180.0, 197.5, 192.5, 202.5, 200.0, 202.5, null, 202.5, 182.5, 190.0, 197.5, 202.5, null, 187.5, 197.5, 195.0, null, null, null, 210.0, 197.5, 202.5, 202.5, 185.0, null, 197.5, 200.0, 187.5, 202.5, 192.5, 187.5, 210.0, 200.0, 187.5, 185.0, 197.5, 202.5, 190.0, 207.5, 190.0, 195.0, 200.0, 197.5, 202.5, 205.0, 200.0, 207.5, 207.5, 190.0, 177.5, null, null, 202.5, 205.0, 205.0, 210.0, 192.5, 192.5,