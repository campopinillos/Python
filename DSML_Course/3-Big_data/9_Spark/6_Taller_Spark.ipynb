# %% [markdown]
# # Sesión 11 - Taller de Spark
#
# En la práctica de hoy vamos a combinar las facilidades del API `DataFrame`de Spark con la librería `Spark MLLib`. Vamos a usar el conjunto de datos conocido como **Titanic**. En Abril 15 de 1912, durante su primer viaje, el Titanic se hundió luego de colisionar con un Iceberg. Allí fallecieron 1502 personas de los 2224 personas a bordo. El objetivo de este conjunto de datos, es analizar las características de los pasajeros que sí sobrevivieron.

# %% [markdown]
# # Carga de datos
# Ejecute los siguientes comandos. Luego, vamos a particionar el conjunto de datos en `training` y `test`.

# %%
# %sh wget "biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv"
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">--2019-06-12 22:28:43--  http://biostat.mc.vanderbilt.edu/wiki/pub/Main/DataSets/titanic3.csv
# Resolving biostat.mc.vanderbilt.edu (biostat.mc.vanderbilt.edu)... 160.129.37.119
# Connecting to biostat.mc.vanderbilt.edu (biostat.mc.vanderbilt.edu)|160.129.37.119|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 116752 (114K) [text/csv]
# Saving to: ‘titanic3.csv’
#
#      0K .......... .......... .......... .......... .......... 43%  237K 0s
#     50K .......... .......... .......... .......... .......... 87%  694K 0s
#    100K .......... ....                                       100%  202K=0.4s
#
# 2019-06-12 22:28:43 (323 KB/s) - ‘titanic3.csv’ saved [116752/116752]
#
# </div>

# %% [markdown]
# Vamos a revisar la ubicación de nuestros archivos con los siguientes comandos:
# * `pwd` nos permite conocer nuestro directorio local.
# * `ls` lista los elementos del directorio local.

# %%
# %sh pwd
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">/databricks/driver
# </div>

# %%
# %sh ls -lah
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">total 232K
# drwxr-xr-x 1 root root 4.0K Jun 12 22:28 .
# drwxr-xr-x 1 root root 4.0K Jun 12 21:19 ..
# drwxr-xr-x 2 root root 4.0K Jan  1  1970 conf
# -rw-r--r-- 1 root root  731 Jun 12 21:20 derby.log
# drwxr-xr-x 3 root root 4.0K Jun 12 21:20 eventlogs
# drwxr-xr-x 2 root root 4.0K Jun 12 22:30 ganglia
# drwxr-xr-x 2 root root 4.0K Jun 12 22:00 logs
# -rw-r--r-- 1 root root  28K May  4  2015 test.csv
# -rw-r--r-- 1 root root 115K Feb 15  2010 titanic3.csv
# -rw-r--r-- 1 root root  60K May  4  2015 train.csv
# </div>

# %% [markdown]
# Cargamos `training` y `test` como `DataFrames`

# %%
dataset = (sqlContext
                   .read
                   .format('com.databricks.spark.csv')
                   .options(header='true', inferSchema='true')
                   .load('file:///databricks/driver/titanic3.csv'))
dataset.cache()
dataset.printSchema()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">root
# -- pclass: integer (nullable = true)
# -- survived: integer (nullable = true)
# -- name: string (nullable = true)
# -- sex: string (nullable = true)
# -- age: double (nullable = true)
# -- sibsp: integer (nullable = true)
# -- parch: integer (nullable = true)
# -- ticket: string (nullable = true)
# -- fare: double (nullable = true)
# -- cabin: string (nullable = true)
# -- embarked: string (nullable = true)
# -- boat: string (nullable = true)
# -- body: integer (nullable = true)
# -- home.dest: string (nullable = true)
#
# </div>

# %%
dataset = dataset.select(['survived', 
                          'pclass', 
                          'name', 
                          'sex', 
                          'age', 
                          'sibsp', 
                          'parch', 
                          'ticket', 
                          'fare', 
                          'cabin', 
                          'embarked'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)</td><td>female</td><td>31.0</td><td>1</td><td>0</td><td>345763</td><td>18.0</td><td>null</td><td>S</td></tr><tr><td>20</td><td>1</td><td>3</td><td>Masselmani, Mrs. Fatima</td><td>female</td><td>null</td><td>0</td><td>0</td><td>2649</td><td>7.225</td><td>null</td><td>C</td></tr><tr><td>21</td><td>0</td><td>2</td><td>Fynney, Mr. Joseph J</td><td>male</td><td>35.0</td><td>0</td ...

# %% [markdown]
# # Trabajando con el API `DataFrame`
# ## Operaciones básicas de agrupamiento
#
# Vamos a determinar cuantas personas sobrevivieron en el conjunto de `training`.

# %%
countings = train.groupBy("survived").count()
display(countings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>359</td></tr><tr><td>0</td><td>551</td></tr></tbody></table></div>

# %% [markdown]
# Podemos también contabilizar cuantas personas de sexo masculino sobrevivieron.

# %%
male_countings = train.filter(train.sex == 'male').groupBy("survived").count()
display(male_countings)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>count</th></tr></thead><tbody><tr><td>1</td><td>117</td></tr><tr><td>0</td><td>458</td></tr></tbody></table></div>

# %% [markdown]
# ## Extracción y transformación de características
#
# En esta sección, vamos a construir una nueva característica, la cual va a determinar si un pasajero era menor de edad o no. Para esto, vamos a trabajar con una **función definida por el usuario** o **UDF**. El objetivo de estas funciones es definir una operación a aplicar sobre una columna. En el caso de la siguiente celda de código, definimos la función `set_child()` de forma que reciba un valor que va a corresponder a la edad, posteriormente evalúa si el número es mayor o menor a 18 y regresa 1 o 0 dependiendo del resultado.
#
# Luego, enmascaramos la función `set_child()` en la función de Spark `udfChild`. Es importante especificar el tipo de dato que va a regresar esta función de Spark. Finalmente con `withColumn`, aplicamos la transformación definida en `udfChild` sobre la columna `Age`.

# %%
from pyspark.sql.types import IntegerType
from pyspark.sql.functions import when, lit, col

def set_child(age):
  if (age != age) | (age is None):
    return None
  if age >= 18:
    return 0
  if age < 18:
    return 1
    
udfChild = udf(set_child, IntegerType())
train = train.withColumn('child', udfChild('age'))
test = test.withColumn('child', udfChild('age'))
display(train)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>pclass</th><th>name</th><th>sex</th><th>age</th><th>sibsp</th><th>parch</th><th>ticket</th><th>fare</th><th>cabin</th><th>embarked</th><th>child</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>"Lindeberg-Lind, Mr. Erik Gustaf (""Mr Edward Lingrey"")"</td><td>male</td><td>42.0</td><td>0</td><td>0</td><td>17475</td><td>26.55</td><td>null</td><td>S</td><td>0</td></tr><tr><td>0</td><td>1</td><td>"Rosenshine, Mr. George (""Mr George Thorne"")"</td><td>male</td><td>46.0</td><td>0</td><td>0</td><td>PC 17585</td><td>79.2</td><td>null</td><td>C</td><td>0</td></tr><tr><td>0</td><td>1</td><td>Allison, Miss. Helen Loraine</td><td>female</td><td>2.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>1</td></tr><tr><td>0</td><td>1</td><td>Allison, Mr. Hudson Joshua Creighton</td><td>male</td><td>30.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>0</td></tr><tr><td>0</td><td>1</td><td>
td><td>0</td></tr><tr><td>0</td><td>1</td><td>Clifford, Mr. George Quincy</td><td>0</td><td>null</td><td>0</td><td>0</td><td>110465</td><td>52.0</td><td>A14</td><td>S</td><td>null</td></tr><tr><td>0</td><td>1</td><td>Colley, Mr. Edward Pomeroy</td><td>0</td><td>47.0</td><td>0</td><td>0</td><td>5727</td><td>25.5875</td><td>E58</td><td>S</td><td>0</td></tr><tr><td>0</td><td>1</td><td>Compton, Mr. Alexander Taylor Jr</td><td>0</td><td>37.0</td><td>1</td><td>1</td><td>PC 17756</td><td>83.1583</td><td>E52</td><td>C</td><td>0</td></tr><tr><td>0</td><td>1</td><td>Crafton, Mr. John Bertram</td><td>0</td><td>null</td><td>0</td><td>0</td><td>113791</td><td>26.55</td><td>null</td><td>S</td><td>null</td></tr><tr><td>0</td><td>1</td><td>Crosby, Capt. Edward Gifford</td><td>0</td><td>70.0</td><td>1</ ...

# %% [markdown]
# ### Manejando variables categóricas
# Como pudo observar, `Embarked` es una variable categórica. Spark tiene varias funciones que le permitirán transformar este columna en una variable categórica. Primero debemos transformar este col

# %%
test_embarked = train.groupBy("embarked").count()
display(test_embarked)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>embarked</th><th>count</th></tr></thead><tbody><tr><td>Q</td><td>89</td></tr><tr><td>null</td><td>1</td></tr><tr><td>C</td><td>176</td></tr><tr><td>S</td><td>644</td></tr></tbody></table></div>

# %% [markdown]
# Cada valor representa una ciudad de embarque distinta. A continuación transformaremos cada ciudad por un número, sin embargo, este número no es útil, por lo que lo llevaremos a una representación *OneHot*. Ya que existen dos pasajeros sin registro de su puerto de abordaje, vamos a crear una categoría especial para ellos, también se puede escoger descartarlos.

# %%
from pyspark.ml import Pipeline
from pyspark.ml.feature import StringIndexer, OneHotEncoderEstimator

indexer = StringIndexer(inputCol="embarked", outputCol="embarkedIndex", handleInvalid="keep")
encoder = OneHotEncoderEstimator(inputCols=["embarkedIndex"], outputCols=["embarkedCategorical"])
pipeline = Pipeline(stages=[indexer, encoder])
pipeline = pipeline.fit(train)
train = pipeline.transform(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(train)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>pclass</th><th>name</th><th>sex</th><th>age</th><th>sibsp</th><th>parch</th><th>ticket</th><th>fare</th><th>cabin</th><th>embarked</th><th>child</th><th>embarkedIndex</th><th>embarkedCategorical</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>"Lindeberg-Lind, Mr. Erik Gustaf (""Mr Edward Lingrey"")"</td><td>0</td><td>42.0</td><td>0</td><td>0</td><td>17475</td><td>26.55</td><td>null</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>"Rosenshine, Mr. George (""Mr George Thorne"")"</td><td>0</td><td>46.0</td><td>0</td><td>0</td><td>PC 17585</td><td>79.2</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Allison, Miss. Helen Loraine</td><td>1</td><td>2.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>1</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Allison, Mr. Hudson Joshua Creighton</td><td>0</td><td>30.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>

# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Reemplazando datos nulos
# Una estrategia común es reemplazar los valores nulos por la media o la mediana, sin embargo, Spark nos permite también reemplazar los valores nulos por un valor fijo como:
#
# ```python
# train = train.na.fill(10, subset=['Age'])
# ```
# En el ejemplo de abajo, vamos a usar `Imputer` de Spark para reemplazar los valores nulos por la mediana de cada columna.

# %%
from pyspark.ml.feature import Imputer

imputer = Imputer(inputCols=["age", "fare"], outputCols=["age", "fare"], strategy='median')
model = imputer.fit(train)
train = model.transform(train)
test = model.transform(test)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
display(train)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>pclass</th><th>name</th><th>sex</th><th>age</th><th>sibsp</th><th>parch</th><th>ticket</th><th>fare</th><th>cabin</th><th>embarked</th><th>child</th><th>embarkedIndex</th><th>embarkedCategorical</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>"Lindeberg-Lind, Mr. Erik Gustaf (""Mr Edward Lingrey"")"</td><td>0</td><td>42.0</td><td>0</td><td>0</td><td>17475</td><td>26.55</td><td>null</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>"Rosenshine, Mr. George (""Mr George Thorne"")"</td><td>0</td><td>46.0</td><td>0</td><td>0</td><td>PC 17585</td><td>79.2</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Allison, Miss. Helen Loraine</td><td>1</td><td>2.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>1</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Allison, Mr. Hudson Joshua Creighton</td><td>0</td><td>30.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Andrews, Mr. Thomas Jr</td><td>0</td><td>39.0</td><td>0</td><td>0</td><td>112050</td><td>0.0</td><td>A36</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Artagaveytia, Mr. Ramon</td><td>0</td><td>71.0</td><td>0</td><td>0</td><td>PC 17609</td><td>49.5042</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Beattie, Mr. Thomson</td><td>0</td><td>36.0</td><td>0</td><td>0</td><td>13050</td><td>75.2417</td><td>C6</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Birnbaum, Mr. Jakob</td><td>0</td><td>25.0</td><td>0</td><td>0</td><td>13905</td><td>26.0</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Blackwell, Mr. Stephen Weart</td><td>0</td><td>45.0</td><td>0</td><td>0</td><td>113784</td><td>35.5</td><td>T</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Borebank, Mr. John James</td><td>0</td><td>42.0</td><td>0</td><td>0</td><td>110489</td><td>26.55</td><td>D22</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Brady, Mr. John Bertram</td><td>0</td><td>41.0</td><td>0</td><td>0</td><td>113054</td><td>30.5</td><td>A21</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Brewe, Dr. Arthur Jackson</td><td>0</td><td>28.0</td><td>0</td><td>0</td><td>112379</td><td>39.6</td><td>null</td><td>C</td><td>null</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Butt, Major. Archibald Willingham</td><td>0</td><td>45.0</td><td>0</td><td>0</td><td>113050</td><td>26.55</td><td>B38</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>
List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Dulles, Mr. William Crothers</td><td>0</td><td>39.0</td><td>0</td><td>0</td><td>PC 17580</td><td>29.7</td><td>A18</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Fortune, Mr. Mark</td><td>0</td><td>64.0</td><td>1</td><td>4</td><td>19950</td><td>263.0</td><td>C23 C25 C27</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Fry, Mr. Richard</td><td>0</td><td>28.0</td><td>0</td><td>0</td><td>112058</td><td>0.0</td><td>B102</td><td>S</td><td>null</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Giglio, Mr. Victor</td><td>0</td><td>24.0</td><td>0</td><td>0</td><td>PC 17593</td><td>79.2</td><td>B86</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td></tr><tr><td>0</td><td>1</td><td>Harrington, Mr. Charles H</td><td>0</td><td>28.0</td><td>0</td><td>0</td><td>113796 ...

# %% [markdown]
# ## Construcción de una matriz de características.

# %%
from pyspark.ml.feature import StringIndexer
from pyspark.ml.feature import VectorAssembler

target_labeler = StringIndexer(inputCol='survived', outputCol='label').fit(train)

train_set = target_labeler.transform(train)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
assembler = VectorAssembler(
 inputCols=['pclass', 'sex','age', 'fare', 'embarkedCategorical'],
 outputCol="features")

train_set = assembler.transform(train_set)
test_set = assembler.transform(test)
test_set = target_labeler.transform(test_set)

display(train_set)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>pclass</th><th>name</th><th>sex</th><th>age</th><th>sibsp</th><th>parch</th><th>ticket</th><th>fare</th><th>cabin</th><th>embarked</th><th>child</th><th>embarkedIndex</th><th>embarkedCategorical</th><th>label</th><th>features</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>"Lindeberg-Lind, Mr. Erik Gustaf (""Mr Edward Lingrey"")"</td><td>0</td><td>42.0</td><td>0</td><td>0</td><td>17475</td><td>26.55</td><td>null</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 42.0, 26.55, 1.0, 0.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>"Rosenshine, Mr. George (""Mr George Thorne"")"</td><td>0</td><td>46.0</td><td>0</td><td>0</td><td>PC 17585</td><td>79.2</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 46.0, 79.2, 0.0, 1.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Allison, Miss. Helen Loraine</td><td>1</td><td>2.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>1</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 1.0, 2.0, 151.55, 1.0, 0.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Allison, Mr. Hudson Joshua Creighton</td><td>0</td><td>30.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 30.0, 151.55, 1.0, 0.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Andrews, Mr. Thomas Jr</td><td>0</td><td>39.0</td><td>0</td><td>0</td><td>112050</td><td>0.0</td><td>A36</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(0, 7, List(0, 2, 4), List(1.0, 39.0, 1.0))</td></tr><tr><td>0</td><td>1</td><td>Artagaveytia, Mr. Ramon</td><td>0</td><td>71.0</td><td>0</td><td>0</td><td>PC 17609</td><td>49.5042</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 71.0, 49.5042, 0.0, 1.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Beattie, Mr. Thomson</td><td>0</td><td>36.0</td><td>0</td><td>0</td><td>13050</td><td>75.2417</td><td>C6</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 36.0, 75.2417, 0.0, 1.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Birnbaum, Mr. Jakob</td><td>0</td><td>25.0</td><td>0</td><td>0</td><td>13905</td><td>26.0</td><td>null</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 25.0, 26.0, 0.0, 1.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Blackwell, Mr. Stephen Weart</td><td>0</td><td>45.0</td><td>0</td><td>0</td><td>113784</td><td>35.5</td><td>T</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 45.0, 35.5, 1.0, 0.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Borebank, Mr. John James</td><td>0</td><td>42.0</td><td>0</td><td>0</td><td>110489</td><td>26.55</td><td>D22</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 42.0, 26.55, 1.0, 0.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Brady, Mr. John Bertram</td><td>0</td><td>41.0</td><td>0</td><td>0</td><td>113054</td><td>30.5</td><td>A21</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List(1.0, 0.0, 41.0, 30.5, 1.0, 0.0, 0.0))</td></tr><tr><td>0</td><td>1</td><td>Brewe, Dr. Arthur Jackson</td><td>0</td><td>28.0</td><td>0</td><td>0</td><td>112379</td><td>39.6</td><td>null</td><td>C</td><td>null</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>0.0</td><td>List(1, 7, List(), List( ...

# %% [markdown]
# ## Definimos una función de evaluación

# %%
from pyspark.ml.evaluation import MulticlassClassificationEvaluator

def evaluate(model, dataset):
  predictions = model.transform(dataset)
  #display(predictions)
  evaluator = MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
                                                metricName="accuracy")
  accuracy = evaluator.evaluate(predictions)
  print("Set accuracy = " + str(accuracy))
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %% [markdown]
# ## Entrenamos un árbol de decisión

# %%
from pyspark.ml.classification import DecisionTreeClassifier

model = DecisionTreeClassifier(maxDepth=2).fit(train_set)
evaluate(model, train_set)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Set accuracy = 0.7857142857142857
# </div>

# %%
evaluate(model, test_set)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Set accuracy = 0.7944862155388471
# </div>

# %% [markdown]
# ## Análisis de los resultados

# %% [markdown]
# Evaluamos las reglas del árbol

# %%
print(model.toDebugString)
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">DecisionTreeClassificationModel (uid=DecisionTreeClassifier_d38b4f11dfeb) of depth 2 with 7 nodes
#   If (feature 1 &lt;= 0.5)
#    If (feature 2 &lt;= 9.5)
#     Predict: 1.0
#    Else (feature 2 &gt; 9.5)
#     Predict: 0.0
#   Else (feature 1 &gt; 0.5)
#    If (feature 0 &lt;= 2.5)
#     Predict: 1.0
#    Else (feature 0 &gt; 2.5)
#     Predict: 0.0
#
# </div>

# %%
predictions = model.transform(test_set)
display(predictions)
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>survived</th><th>pclass</th><th>name</th><th>sex</th><th>age</th><th>sibsp</th><th>parch</th><th>ticket</th><th>fare</th><th>cabin</th><th>embarked</th><th>child</th><th>embarkedIndex</th><th>embarkedCategorical</th><th>features</th><th>label</th><th>rawPrediction</th><th>probability</th><th>prediction</th></tr></thead><tbody><tr><td>0</td><td>1</td><td>Allison, Mrs. Hudson J C (Bessie Waldo Daniels)</td><td>1</td><td>25.0</td><td>1</td><td>2</td><td>113781</td><td>151.55</td><td>C22 C26</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>List(1, 7, List(), List(1.0, 1.0, 25.0, 151.55, 1.0, 0.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(15.0, 171.0))</td><td>List(1, 2, List(), List(0.08064516129032258, 0.9193548387096774))</td><td>1.0</td></tr><tr><td>0</td><td>1</td><td>Astor, Col. John Jacob</td><td>0</td><td>47.0</td><td>1</td><td>0</td><td>PC 17757</td><td>227.525</td><td>C62 C64</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 47.0, 227.525, 0.0, 1.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Baumann, Mr. John D</td><td>0</td><td>28.0</td><td>0</td><td>0</td><td>PC 17318</td><td>25.925</td><td>null</td><td>S</td><td>null</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 28.0, 25.925, 1.0, 0.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Baxter, Mr. Quigg Edmond</td><td>0</td><td>24.0</td><td>0</td><td>1</td><td>PC 17558</td><td>247.5208</td><td>B58 B60</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 24.0, 247.5208, 0.0, 1.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Brandeis, Mr. Emil</td><td>0</td><td>48.0</td><td>0</td><td>0</td><td>PC 17591</td><td>50.4958</td><td>B10</td><td>C</td><td>0</td><td>1.0</td><td>List(0, 3, List(1), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 48.0, 50.4958, 0.0, 1.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Cairns, Mr. Alexander</td><td>0</td><td>28.0</td><td>0</td><td>0</td><td>113798</td><td>31.0</td><td>null</td><td>S</td><td>null</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 28.0, 31.0, 1.0, 0.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Carlsson, Mr. Frans Olof</td><td>0</td><td>33.0</td><td>0</td><td>0</td><td>695</td><td>5.0</td><td>B51 B53 B55</td><td>S</td><td>0</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 33.0, 5.0, 1.0, 0.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Carrau, Mr. Jose Pedro</td><td>0</td><td>17.0</td><td>0</td><td>0</td><td>113059</td><td>47.1</td><td>null</td><td>S</td><td>1</td><td>0.0</td><td>List(0, 3, List(0), List(1.0))</td><td>List(1, 7, List(), List(1.0, 0.0, 17.0, 47.1, 1.0, 0.0, 0.0))</td><td>0.0</td><td>List(1, 2, List(), List(447.0, 98.0))</td><td>List(1, 2, List(), List(0.8201834862385321, 0.1798165137614679))</td><td>0.0</td></tr><tr><td>0</td><td>1</td><td>Chisholm, Mr. Roderick Robe ...

# %% [markdown]
# Use la opción de graficar y evalúe visualmente la correspondencia entre edad y supervivencia

# %%
display(predictions.select("age", "survived"))
# Out:
# <style scoped>
#   .table-result-container {
#     max-height: 300px;
#     overflow: auto;
#   }
#   table, th, td {
#     border: 1px solid black;
#     border-collapse: collapse;
#   }
#   th, td {
#     padding: 5px;
#   }
#   th {
#     text-align: left;
#   }
# </style><div class='table-result-container'><table class='table-result'><thead style='background-color: white'><tr><th>age</th><th>survived</th></tr></thead><tbody><tr><td>25.0</td><td>0</td></tr><tr><td>47.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>24.0</td><td>0</td></tr><tr><td>48.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>33.0</td><td>0</td></tr><tr><td>17.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>27.0</td><td>0</td></tr><tr><td>31.0</td><td>0</td></tr><tr><td>50.0</td><td>0</td></tr><tr><td>39.0</td><td>0</td></tr><tr><td>64.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>24.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>55.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>46.0</td><td>0</td></tr><tr><td>58.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>30.0</td><td>0</td></tr><tr><td>28
0</td><td>0</td></tr><tr><td>18.0</td><td>0</td></tr><tr><td>27.0</td><td>0</td></tr><tr><td>19.0</td><td>0</td></tr><tr><td>26.0</td><td>0</td></tr><tr><td>21.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>40.0</td><td>0</td></tr><tr><td>20.0</td><td>0</td></tr><tr><td>22.0</td><td>0</td></tr><tr><td>35.0</td><td>0</td></tr><tr><td>18.0</td><td>0</td></tr><tr><td>17.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>28.0</td><td>0</td></tr><tr><td>21.0</td><td>0</td></tr><tr><td>29.0</td><td>0</td></tr><tr><td>36.0</td><td>0</td></tr><tr><td>31.0</td><td>0</td></tr><tr><td>30.0</td><td>0</td></tr><tr><td>43.0</td><td>0</td></tr><tr><td>27.0</td><td>0</td></t ...

# %% [markdown]
# # Taller
#
# En este taller, vamos a trabajar con el mismo conjunto de datos, pero vamos a usar `Random Forest` y a estudiar como realizar validación cruzada. En el caso de validación cruzada, su objetivo será explorar el número subóptimo de árboles para resolver este problema.
#
# * Validación cruzada:
# Ahora queremos explorar el conjunto de parámetros subóptimo para nuestro modelo. Para esto, generamos una grilla de parámetros para explorar el número óptimo de árboles. Para estos creamos una instancia de `ParamGridBuilder()`, donde especificaremos el parámetros como el conjunto de parámetros que vamos a explorar. Posteriormente, creamos un objeto de tipo `CrossValidator`, dónde especificamos el modelo que queremos validar, el conjunto de parámetros que vamos a explorar, la medida de desempeño a usar, y el número de folds. Finalmente llamamos a la función `fit()` sobre el conjunto de entrenamiento. Use el siguiente código como base:
#
# ```python
# from pyspark.ml.classification import RandomForestClassifier
# from pyspark.ml.tuning import CrossValidator, ParamGridBuilder
#
# model = RandomForestClassifier()
# paramGrid = ParamGridBuilder() \
#     .addGrid(model.numTrees, [5, 10, 15, 20, 25, 50]) \
#     .build()
#
# crossval = CrossValidator(estimator=model,
#                           estimatorParamMaps=paramGrid,
#                           evaluator=MulticlassClassificationEvaluator(labelCol="label", predictionCol="prediction",
#                                                 metricName="accuracy"),
#                           numFolds=5)
#
# cvModel = crossval.fit(trainSet)
# ```
# * `cvModel` puede ser usado como cualquier modelo ya entrenado. Use la función `evaluate` y mida el desempeño sobre el conjunto de prueba.
# ```python
# evaluate(cvModel, testSet)
# ```
# * Visualice la curva de complejidad en Spark usando la siguiente función:
# ```python
# exploration = sqlContext.createDataFrame(zip([5, 10, 15, 20, 25, 50], cvModel.avgMetrics), ['numTrees', 'score'])
# display(exploration)
# ```

# %% [markdown]
# # Entregables
# Vaya a la parte superior y descargue como html este notebook, luego renombrelo así:
#
# * s11_nombre_apellido.html
#
# Y envíelo a la siguiente solicitud de archivos:
# [Dropbox link](https://www.dropbox.com/request/T8oiFuVbiUm8pzhB9f4w)
#
# Fecha de entrega: Lunes 22 de Julio de 2019

# %% [markdown]
# # Ayuda
# * Documentación detallada de PySpark: https://spark.apache.org/docs/2.3.1/api/python/pyspark.ml.html
# * Documentación con ejemplo de Spark MLLib: https://spark.apache.org/docs/2.3.1/ml-features.html
